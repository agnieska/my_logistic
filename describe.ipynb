# %%
# !pip3 install numpy
# Out:
# Requirement already satisfied: numpy in /home/agnieska/.local/lib/python3.7/site-packages (1.16.3)

# %%
# !pip3 install pandas
# Out:
# Requirement already satisfied: pandas in /home/agnieska/.local/lib/python3.7/site-packages (0.24.2)
# Requirement already satisfied: pytz>=2011k in /home/agnieska/.local/lib/python3.7/site-packages (from pandas) (2019.1)
# Requirement already satisfied: numpy>=1.12.0 in /home/agnieska/.local/lib/python3.7/site-packages (from pandas) (1.16.3)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/lib/python3/dist-packages (from pandas) (2.7.3)

# %%
import numpy as np
import pandas as pd
from pprint import pprint
import math

# %%
data_train = pd.read_csv("resources/dataset_train.csv")
data_test = pd.read_csv("resources/dataset_test.csv")

# %%
data_train.head(10)
# Out:
#    Index Hogwarts House First Name   Last Name    Birthday Best Hand  \
# 0      0      Ravenclaw     Tamara         Hsu  2000-03-30      Left
# 1      1      Slytherin      Erich     Paredes  1999-10-14     Right
# 2      2      Ravenclaw   Stephany       Braun  1999-11-03      Left
# 3      3     Gryffindor      Vesta   Mcmichael  2000-08-19      Left
# 4      4     Gryffindor     Gaston       Gibbs  1998-09-27      Left
# 5      5      Slytherin    Corrine     Hammond  1999-04-04     Right
# 6      6     Gryffindor        Tom       Guido  2000-09-30      Left
# 7      7     Hufflepuff     Alicia     Hayward  1997-07-08     Right
# 8      8     Gryffindor      Bella  Leatherman  1998-12-07      Left
# 9      9     Hufflepuff     Hayden      Aponte  2001-10-13     Right
#
#    Arithmancy   Astronomy  Herbology  Defense Against the Dark Arts  \
# 0     58384.0 -487.886086   5.727180                       4.878861
# 1     67239.0 -552.060507  -5.987446                       5.520605
# 2     23702.0 -366.076117   7.725017                       3.660761
# 3     32667.0  697.742809  -6.497214                      -6.977428
# 4     60158.0  436.775204  -7.820623                            NaN
# 5     21209.0 -613.687160  -4.289197                       6.136872
# 6     49167.0  628.046051  -4.861976                      -6.280461
# 7     33010.0  411.412727   5.931832                      -4.114127
# 8     20278.0  496.394945  -5.215891                      -4.963949
# 9     46316.0  527.193585   7.922205                      -5.271936
#
#    Divination  Muggle Studies  Ancient Runes  History of Magic  \
# 0       4.722      272.035831     532.484226          5.231058
# 1      -5.612     -487.340557     367.760303          4.107170
# 2       6.140      664.893521     602.585284          3.555579
# 3       4.026     -537.001128     523.982133         -4.809637
# 4       2.236     -444.262537     599.324514         -3.444377
# 5      -6.592     -440.997704     396.201804          5.380286
# 6         NaN     -926.892512     583.742442         -7.322486
# 7       2.769     -502.021336     439.351416               NaN
# 8       5.855     -626.552041     567.842402         -6.198661
# 9       3.356     -398.101991     341.475606          4.978614
#
#    Transfiguration    Potions  Care of Magical Creatures     Charms  Flying
# 0      1039.788281   3.790369                   0.715939 -232.79405  -26.89
# 1      1058.944592   7.248742                   0.091674 -252.18425 -113.45
# 2      1088.088348   8.728531                  -0.515327 -227.34265   30.42
# 3       920.391449   0.821911                  -0.014040 -256.84675  200.64
# 4       937.434724   4.311066                  -0.264070 -256.38730  157.98
# 5      1052.845164  11.751212                   1.049894 -247.94549  -34.69
# 6       923.539573   1.646666                   0.153022 -257.83447  261.55
# 7      1041.091935   6.581791                  -0.171704 -244.03492   72.25
# 8       925.255500   1.086518                   1.147032 -252.27561  244.11
# 9      1041.414665   2.068824                  -0.529579 -244.57527   -0.09

# %%
data_test.head(100)
# Out:
#     Index  Hogwarts House First Name    Last Name    Birthday Best Hand  \
# 0       0             NaN       Rico      Sargent  2001-10-06     Right
# 1       1             NaN     Tamara  Shackelford  1998-01-08      Left
# 2       2             NaN      Staci     Crandall  1998-09-15      Left
# 3       3             NaN        Dee        Gavin  2001-05-10     Right
# 4       4             NaN    Gregory    Gustafson  1999-02-01     Right
# 5       5             NaN  Katharine        Ebert  1998-09-25      Left
# 6       6             NaN  Elizebeth      Clemens  1998-12-16      Left
# 7       7             NaN      Santo     Simonson  1999-01-04      Left
# 8       8             NaN    Rosalyn          Gee  1997-09-01      Left
# 9       9             NaN      Karen       Skaggs  2001-08-11      Left
# 10     10             NaN     Mollie      Donohue  1999-07-07     Right
# 11     11             NaN  Filiberto        Beebe  2000-01-09      Left
# 12     12             NaN     Carmen   Washington  1998-02-18     Right
# 13     13             NaN    Milford        Bader  2000-02-01     Right
# 14     14             NaN  Nathanael      Holland  1997-08-08     Right
# 15     15             NaN      Nilda       Peyton  2001-06-16     Right
# 16     16             NaN      Tasha        Lyons  1997-11-30      Left
# 17     17             NaN     Briana      Diamond  1999-12-24      Left
# 18     18             NaN      Belle       Jasper  2001-01-28      Left
# 19     19             NaN  Nathanael       Hanson  2000-04-02      Left
# 20     20             NaN      Devin      Velasco  1998-07-11      Left
# 21     21             NaN       Tami      Preston  1999-07-02     Right
# 22     22             NaN      Brook       Zapata  1998-03-10     Right
# 23     23             NaN      Allan       Mcdade  2001-03-20      Left
# 24     24             NaN      Colin        Rouse  1998-08-19     Right
# 25     25             NaN       Olin   Schumacher  2000-11-27     Right
# 26     26             NaN     Freddy     Jernigan  1997-06-01     Right
# 27     27             NaN    Kristal         Beck  1999-12-21     Right
# 28     28             NaN  Magdalena      English  2000-03-02     Right
# 29     29             NaN     Lemuel   Huddleston  1998-08-23      Left
# ..    ...             ...        ...          ...         ...       ...
# 70     70             NaN   Benedict  Christopher  1998-01-27     Right
# 71     71             NaN     Birdie       Haller  2000-07-22     Right
# 72     72             NaN    Wilford        Parks  1996-12-30      Left
# 73     73             NaN    Eleanor       Nathan  1997-11-23     Right
# 74     74             NaN      Chang      Tallent  1999-09-15      Left
# 75     75             NaN     Elbert        Potts  1999-05-13      Left
# 76     76             NaN      Keven        Hager  1999-01-10      Left
# 77     77             NaN    Lynwood       Almond  1997-10-19     Right
# 78     78             NaN    Renaldo          Ngo  1996-12-08      Left
# 79     79             NaN       Myra        Wiley  1997-05-06      Left
# 80     80             NaN    Chantal    Macdonald  1999-12-06     Right
# 81     81             NaN     Luella       Fuller  1999-12-25     Right
# 82     82             NaN     Wilbur       Salley  1999-08-25      Left
# 83     83             NaN    Manuela       Tucker  1997-11-30     Right
# 84     84             NaN       Lupe       Myrick  1999-03-23     Right
# 85     85             NaN    Earline   Singletary  2000-02-13     Right
# 86     86             NaN    Mohamed        Wills  2001-05-03      Left
# 87     87             NaN     Danilo      Whiting  1999-09-04      Left
# 88     88             NaN    Alberta       Tomlin  1999-08-17     Right
# 89     89             NaN      Bruce       Mccool  2000-09-08      Left
# 90     90             NaN     Andria         Lees  1996-12-03      Left
# 91     91             NaN      Erwin      Knudsen  2001-10-01     Right
# 92     92             NaN    Jerrold        Lynch  1999-05-29     Right
# 93     93             NaN      Keven      Emanuel  2000-07-11     Right
# 94     94             NaN       Otto        Muniz  1998-08-24     Right
# 95     95             NaN    Domingo      Maloney  1997-12-16     Right
# 96     96             NaN        Jon    Patterson  1999-01-25     Right
# 97     97             NaN      Devin   Kuykendall  1999-06-29     Right
# 98     98             NaN       Dara         Doty  1997-07-05     Right
# 99     99             NaN      Jonas       Worthy  2001-06-25      Left
#
#     Arithmancy   Astronomy  Herbology  Defense Against the Dark Arts  \
# 0      41642.0  696.096071   3.020172                      -6.960961
# 1      45352.0 -370.844655   2.965226                       3.708447
# 2      43502.0  320.303990  -6.185697                      -3.203040
# 3      61831.0  407.202928   4.962442                            NaN
# 4          NaN  288.337747   3.737656                      -2.883377
# 5      60888.0 -482.139096  -7.327170                       4.821391
# 6      46583.0 -488.041453   4.276266                       4.880415
# 7      42013.0  675.144048   4.024691                      -6.751440
# 8      27434.0 -508.767001   7.146465                       5.087670
# 9      33500.0  319.886372   6.558003                      -3.198864
# 10     47320.0  838.688044   7.307271                      -8.386880
# 11     46821.0 -592.840040  -5.193860                       5.928400
# 12     54547.0 -420.425944  -7.862746                       4.204259
# 13     60483.0 -425.915361  -4.563681                       4.259154
# 14     46012.0 -424.855107  -2.860624                       4.248551
# 15     58059.0  511.393084   4.554058                            NaN
# 16     40414.0 -287.404638   4.573500                       2.874046
# 17     54521.0 -432.933326  -4.616781                       4.329333
# 18     37327.0 -370.149445   6.090902                       3.701494
# 19     46165.0  593.007329   1.657753                      -5.930073
# 20     68803.0  349.869729   6.464247                      -3.498697
# 21     52568.0 -385.809381  -4.962466                       3.858094
# 22     10167.0 -315.589549   2.299019                       3.155895
# 23     74358.0 -577.375308   3.409038                       5.773753
# 24     55346.0  610.038005        NaN                      -6.100380
# 25     37040.0  383.700576   3.520115                      -3.837006
# 26     40696.0 -537.650990   1.431912                       5.376510
# 27     65263.0 -438.722018        NaN                       4.387220
# 28     72647.0  535.691919  -4.712874                      -5.356919
# 29     63929.0 -610.485645   3.032363                       6.104856
# ..         ...         ...        ...                            ...
# 70     41725.0 -546.203406  -6.296242                       5.462034
# 71     57714.0 -388.385532  -5.343483                       3.883855
# 72         NaN  734.783417  -3.744274                      -7.347834
# 73     32066.0 -409.726303   6.036502                       4.097263
# 74     54865.0  353.054362  -3.969736                      -3.530544
# 75     44605.0  513.055182   5.796347                      -5.130552
# 76     35535.0  582.903295   4.841549                      -5.829033
# 77         NaN  291.022048  -6.255450                      -2.910220
# 78      4536.0 -385.776970   3.049900                       3.857770
# 79     37200.0         NaN  -5.004776                      -6.050063
# 80     43735.0 -628.370555   0.673023                       6.283706
# 81     70453.0  463.338651   7.014549                      -4.633387
# 82     72488.0 -334.867103  -6.544688                       3.348671
# 83     42474.0  556.820986  -6.025279                      -5.568210
# 84     68654.0  413.460801        NaN                      -4.134608
# 85     63385.0  396.317724   3.510742                      -3.963177
# 86     62249.0  481.915427   3.630490                      -4.819154
# 87     49230.0  427.850261   7.144357                      -4.278503
# 88     59914.0 -511.076256   6.718754                       5.110763
# 89     46922.0 -376.017237   8.201982                       3.760172
# 90     71589.0  369.195264   4.549809                      -3.691953
# 91     37106.0 -669.937361  -5.393879                       6.699374
# 92     70896.0  477.204054  -6.358316                      -4.772041
# 93     52045.0  533.852526   6.492319                      -5.338525
# 94     46717.0 -636.881812   6.183190                       6.368818
# 95     29432.0 -463.221120   3.186254                       4.632211
# 96     23761.0  694.996839  -5.212564                      -6.949968
# 97     72835.0 -488.390242  -5.619551                       4.883902
# 98     38819.0         NaN   5.405685                            NaN
# 99     79908.0 -488.546117   2.590905                       4.885461
#
#     Divination  Muggle Studies  Ancient Runes  History of Magic  \
# 0        7.996     -365.151850     393.138185          4.207691
# 1        6.349      522.580486     602.853051          6.460017
# 2        4.619     -630.073207     588.071795         -5.565818
# 3          NaN     -449.179806     427.699966               NaN
# 4        4.886     -449.732166     385.712782          2.876347
# 5       -6.611     -525.272503     359.148172          5.197858
# 6        4.916      408.925474     633.733002          3.577942
# 7        5.108     -590.514804     409.420643          4.672595
# 8        4.586      512.850134     591.524186          3.129792
# 9        2.652     -449.926595     415.734688          4.754587
# 10       4.148     -461.481430     350.370918          1.788637
# 11      -5.205             NaN     392.494003          4.430113
# 12      -2.059     -240.325146     474.237203          5.936735
# 13      -6.922     -487.782823     386.209644          3.179448
# 14      -4.828     -538.453520     422.411305          2.599355
# 15       5.257     -621.180143     320.321590          7.445044
# 16       6.236      324.444712     587.169766          3.185661
# 17      -4.632     -709.282606     386.199391          4.102166
# 18       6.211      617.664751     615.176119          3.171364
# 19       3.995     -552.953585     365.374221          5.392874
# 20       4.254     -679.820877     353.044430               NaN
# 21      -5.292     -462.012835     423.394939          5.459748
# 22       5.292       80.602778     550.501007          3.176449
# 23       5.177      804.435862     640.245804          5.218387
# 24       7.051     -615.230181     486.508729          4.694029
# 25       4.267     -282.053033     400.151616          6.754121
# 26       4.129      595.047050     637.166237          6.513187
# 27      -6.131     -403.672441     400.888868          4.658475
# 28       4.531     -430.609289     631.476283         -4.420345
# 29       4.605      609.075704     605.406715          3.542074
# ..         ...             ...            ...               ...
# 70      -4.250     -223.807952     427.244903          5.485724
# 71      -6.942     -545.608623     390.622573          2.840615
# 72       5.384     -616.081350     604.675275         -4.786549
# 73       5.417      169.477643     581.404695          5.401560
# 74       6.452     -288.705316     625.865690               NaN
# 75       6.313     -413.810521     451.374646          4.973513
# 76       2.992     -386.913471     433.455152          3.726788
# 77       3.951     -466.281498     593.490317         -5.191954
# 78       4.361      333.726412     562.318027          3.517562
# 79       4.689     -947.767917     546.677898         -6.411736
# 80       3.226      693.805458     589.585300          4.419398
# 81       3.547     -551.947492     352.069643          3.209856
# 82      -3.515     -671.252327     396.498075          5.662488
# 83       4.185     -691.910803     573.642185         -4.083572
# 84       5.488     -653.329914     600.096179         -6.774123
# 85       4.593     -407.494571     396.539211          9.095451
# 86       3.701     -660.065701     468.523886          4.810437
# 87       4.481     -621.960877     396.900118          1.962218
# 88       6.098      585.633652     554.751368          2.389434
# 89       6.007      485.348334     591.317754          4.482976
# 90       4.936     -541.643376     415.249522               NaN
# 91      -5.212     -830.799627     323.734240          7.384315
# 92       2.684     -643.802114     580.109988         -5.263806
# 93       3.942             NaN     418.646445          2.232404
# 94       4.817      770.389618     568.789271          5.711948
# 95       4.853      463.718296     591.321406          4.532001
# 96       5.213     -774.091146     576.330325         -3.962911
# 97      -5.062     -397.995468     408.553453          4.925188
# 98       3.787     -241.397110     383.495021          8.980822
# 99       5.573      686.046409     624.111617          5.093841
#
#     Transfiguration    Potions  Care of Magical Creatures     Charms  Flying
# 0       1046.742736   3.668983                   0.373853 -244.48172  -13.62
# 1       1048.053878   8.514622                   0.577432 -231.29200  -26.26
# 2        936.437358   1.850829                  -1.647150 -252.99343  200.15
# 3       1043.397718   4.656573                   1.164708 -244.01660  -11.15
# 4       1051.377936   2.750586                   0.102104 -243.99806   -7.12
# 5       1070.712143  10.032461                  -2.185220 -253.62839 -126.66
# 6       1046.217172   7.922500                  -1.178456 -231.58560   32.67
# 7       1056.701013   7.132861                   0.563118 -245.93425   13.45
# 8       1040.734232   5.783287                   0.419334 -229.42604   60.88
# 9       1036.405617   5.773882                  -0.184082 -242.76836   46.29
# 10      1049.355137   1.582543                  -1.304366 -247.98054   38.54
# 11      1054.170714   8.897999                   0.202673 -249.41488  -74.31
# 12      1031.385628  10.539316                  -2.196524 -248.69091  -80.08
# 13      1057.987562   8.495121                   0.758081 -253.07643  -63.92
# 14      1056.327058   9.072908                  -1.005776 -249.44113  -16.04
# 15      1069.634669   4.390775                  -0.875848 -245.17056  -90.75
# 16      1039.069611   5.818117                   0.143678 -232.80601   36.26
# 17      1072.930510   9.916366                   1.628481 -250.88116  -75.58
# 18      1070.323984   7.529849                   0.098973 -229.40354   24.75
# 19      1068.495597   7.049344                  -0.505510 -247.87798  -44.64
# 20      1068.901380   2.049938                  -1.176780 -245.03147  -39.74
# 21      1038.506724  10.338426                   0.753893 -250.89025  -54.47
# 22      1044.828664   8.365853                  -0.028707 -233.99950   56.19
# 23      1066.551493   7.347293                  -0.941412 -230.77467  -62.86
# 24      1056.009135   8.833560                   0.778869 -244.83219    8.61
# 25      1034.963193   5.883460                  -0.873216 -243.24240  -18.35
# 26      1055.369992  11.540264                   2.134282 -231.51566  -19.59
# 27      1038.386735   8.137329                   1.352075 -252.47707  -78.07
# 28       955.581424   3.509034                   1.019770 -253.76253  167.45
# 29      1064.329086   6.121348                  -0.024521 -232.17381  -38.96
# ..              ...        ...                        ...        ...     ...
# 70      1034.930552   9.558548                   3.205525 -248.38773  -68.97
# 71      1073.195605  10.067926                   1.042155 -253.65697  -65.40
# 72       951.290491   3.676678                        NaN -254.08185  208.13
# 73      1036.316107   7.639175                   0.067168 -230.78352   40.68
# 74       961.889442   1.600663                   0.330381 -249.40930  178.29
# 75      1032.967474   5.312641                        NaN -242.00769   32.94
# 76      1035.051396   6.549407                   0.936139 -245.83222   58.99
# 77       944.939339   0.948743                   1.649182 -254.00180  151.97
# 78              NaN   9.926703                   2.252370 -232.14038   46.80
# 79       926.091637   0.872950                  -0.918140 -256.03311  240.57
# 80      1055.313783   7.903263                  -0.923035 -233.27417  -35.90
# 81      1058.343369   1.074931                  -0.227173 -246.36528  -23.88
# 82      1060.383740   9.652219                  -0.647388 -252.45307 -117.57
# 83       943.712316   3.985278                   0.885157 -254.83519  192.17
# 84       948.693053  -0.125636                   0.365662 -253.15144  192.49
# 85      1047.996523   6.701146                  -0.264253 -243.88771  -82.53
# 86      1058.944463   8.919098                   0.647009 -246.06211   10.49
# 87      1056.132108   2.916695                   0.608718 -244.08299   38.72
# 88      1040.684014   0.637405                   2.204635 -230.92879   -7.64
# 89      1055.746714   5.866438                  -1.739954 -229.20374   18.48
# 90      1058.920354   1.897211                   0.304882 -245.83825   -4.13
# 91      1077.314505  11.118488                  -0.026687 -248.80566 -124.65
# 92       936.716507   1.568148                   0.144382 -257.48158  171.99
# 93      1037.017267   2.712880                  -0.613027 -245.25227   45.85
# 94      1055.491515   5.199295                   1.369632 -228.40478  -38.13
# 95      1041.763593   7.919954                  -0.749163 -231.74768   20.45
# 96       943.673984   5.385684                   0.351316 -253.74136  228.67
# 97      1030.769314   7.028467                  -0.659897 -251.78655  -92.12
# 98      1026.377378   5.809116                   0.166099 -242.18932  -31.48
# 99      1047.660109   5.733112                   0.369767 -232.89752  -61.56
#
# [100 rows x 19 columns]

# %%
data_train['Index'].shape
# Out:
# (1600,)

# %%
data_test['Index'].shape
# Out:
# (400,)

# %%
data_test.columns
# Out:
# Index(['Index', 'Hogwarts House', 'First Name', 'Last Name', 'Birthday',
#        'Best Hand', 'Arithmancy', 'Astronomy', 'Herbology',
#        'Defense Against the Dark Arts', 'Divination', 'Muggle Studies',
#        'Ancient Runes', 'History of Magic', 'Transfiguration', 'Potions',
#        'Care of Magical Creatures', 'Charms', 'Flying'],
#       dtype='object')

# %%
column_names_list = list(data_train.columns)
column_names_list
# Out:
# ['Index',
#  'Hogwarts House',
#  'First Name',
#  'Last Name',
#  'Birthday',
#  'Best Hand',
#  'Arithmancy',
#  'Astronomy',
#  'Herbology',
#  'Defense Against the Dark Arts',
#  'Divination',
#  'Muggle Studies',
#  'Ancient Runes',
#  'History of Magic',
#  'Transfiguration',
#  'Potions',
#  'Care of Magical Creatures',
#  'Charms',
#  'Flying']

# %%
measure_names_list = ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max']

# %%
describe_dict = {}
for column_name in column_names_list[6:] :
    #values = list(train_dict[column_name].values())
    values = list(data_train[column_name])
    #print(type(values[4]))
    values = [x for x in values if (math.isnan(x) == False)]
    #pprint(values[0:5])
    values.sort()
    values = np.array(values)
    describe_dict[column_name]={}
    count = round(len(values),6)
    somme = round(sum(values),6)
    mean = round(somme/count,6)
    variance = round(sum((values - mean)**2)/count, 6)
    #print(variance)
    std = round(variance **0.5,6)
    #print(std)
    count = int(count)
    q25 = int(count*0.25)
    q50 = int(count*0.5)
    q75 = int(count*0.75)
    describe_dict[column_name]['count'] = count
    #describe_dict[column_name]['sum'] = somme
    describe_dict[column_name]['mean'] = mean
    describe_dict[column_name]['std'] = std
    describe_dict[column_name]['min'] = round(values[0],6)
    describe_dict[column_name]['25%'] = round(values[q25],6)
    describe_dict[column_name]['50%'] = round(values[q50],6)
    describe_dict[column_name]['75%'] = round(values[q75],6)
    describe_dict[column_name]['max'] = round(values[-1],6)

# %%
describe_dict
# Out:
# {'Arithmancy': {'count': 1566,
#   'mean': 49634.570243,
#   'std': 16674.479577,
#   'min': -24370.0,
#   '25%': 38510.0,
#   '50%': 49018.0,
#   '75%': 60828.0,
#   'max': 104956.0},
#  'Astronomy': {'count': 1568,
#   'mean': 39.797131,
#   'std': 520.13233,
#   'min': -966.740546,
#   '25%': -489.493777,
#   '50%': 261.644731,
#   '75%': 525.90954,
#   'max': 1016.21194},
#  'Herbology': {'count': 1567,
#   'mean': 1.14102,
#   'std': 5.218016,
#   'min': -10.295663,
#   '25%': -4.312118,
#   '50%': 3.469012,
#   '75%': 5.421046,
#   'max': 11.612895},
#  'Defense Against the Dark Arts': {'count': 1569,
#   'mean': -0.387863,
#   'std': 5.211132,
#   'min': -10.162119,
#   '25%': -5.259095,
#   '50%': -2.589342,
#   '75%': 4.90468,
#   'max': 9.667405},
#  'Divination': {'count': 1561,
#   'mean': 3.15391,
#   'std': 4.15397,
#   'min': -8.727,
#   '25%': 3.099,
#   '50%': 4.624,
#   '75%': 5.667,
#   'max': 10.032},
#  'Muggle Studies': {'count': 1565,
#   'mean': -224.589915,
#   'std': 486.189433,
#   'min': -1086.496835,
#   '25%': -577.580096,
#   '50%': -419.164294,
#   '75%': 254.994857,
#   'max': 1092.388611},
#  'Ancient Runes': {'count': 1565,
#   'mean': 495.74797,
#   'std': 106.251202,
#   'min': 283.869609,
#   '25%': 397.511047,
#   '50%': 463.918305,
#   '75%': 597.49223,
#   'max': 745.39622},
#  'History of Magic': {'count': 1557,
#   'mean': 2.963095,
#   'std': 4.424353,
#   'min': -8.858993,
#   '25%': 2.218653,
#   '50%': 4.378176,
#   '75%': 5.825242,
#   'max': 11.889713},
#  'Transfiguration': {'count': 1566,
#   'mean': 1030.096946,
#   'std': 44.111025,
#   'min': 906.62732,
#   '25%': 1026.171713,
#   '50%': 1045.533335,
#   '75%': 1058.445388,
#   'max': 1098.958201},
#  'Potions': {'count': 1570,
#   'mean': 5.950373,
#   'std': 3.146852,
#   'min': -4.697484,
#   '25%': 3.6449,
#   '50%': 5.877582,
#   '75%': 8.248789,
#   'max': 13.536762},
#  'Care of Magical Creatures': {'count': 1560,
#   'mean': -0.053427,
#   'std': 0.971146,
#   'min': -3.313676,
#   '25%': -0.670996,
#   '50%': -0.043296,
#   '75%': 0.594446,
#   'max': 3.056546},
#  'Charms': {'count': 1600,
#   'mean': -243.374409,
#   'std': 8.780895,
#   'min': -261.04892,
#   '25%': -250.64727,
#   '50%': -244.86751,
#   '75%': -232.53675,
#   'max': -225.42814},
#  'Flying': {'count': 1600,
#   'mean': 21.958012,
#   'std': 97.601087,
#   'min': -181.47,
#   '25%': -41.84,
#   '50%': -2.51,
#   '75%': 50.89,
#   'max': 279.07}}

# %%
df = pd.DataFrame(describe_dict)

# %%
df.head(10)
# Out:
#           Arithmancy    Astronomy    Herbology  Defense Against the Dark Arts  \
# 25%     38510.000000  -489.493777    -4.312118                      -5.259095
# 50%     49018.000000   261.644731     3.469012                      -2.589342
# 75%     60828.000000   525.909540     5.421046                       4.904680
# count    1566.000000  1568.000000  1567.000000                    1569.000000
# max    104956.000000  1016.211940    11.612895                       9.667405
# mean    49634.570243    39.797131     1.141020                      -0.387863
# min    -24370.000000  -966.740546   -10.295663                     -10.162119
# std     16674.479577   520.132330     5.218016                       5.211132
#
#        Divination  Muggle Studies  Ancient Runes  History of Magic  \
# 25%       3.09900     -577.580096     397.511047          2.218653
# 50%       4.62400     -419.164294     463.918305          4.378176
# 75%       5.66700      254.994857     597.492230          5.825242
# count  1561.00000     1565.000000    1565.000000       1557.000000
# max      10.03200     1092.388611     745.396220         11.889713
# mean      3.15391     -224.589915     495.747970          2.963095
# min      -8.72700    -1086.496835     283.869609         -8.858993
# std       4.15397      486.189433     106.251202          4.424353
#
#        Transfiguration      Potions  Care of Magical Creatures       Charms  \
# 25%        1026.171713     3.644900                  -0.670996  -250.647270
# 50%        1045.533335     5.877582                  -0.043296  -244.867510
# 75%        1058.445388     8.248789                   0.594446  -232.536750
# count      1566.000000  1570.000000                1560.000000  1600.000000
# max        1098.958201    13.536762                   3.056546  -225.428140
# mean       1030.096946     5.950373                  -0.053427  -243.374409
# min         906.627320    -4.697484                  -3.313676  -261.048920
# std          44.111025     3.146852                   0.971146     8.780895
#
#             Flying
# 25%     -41.840000
# 50%      -2.510000
# 75%      50.890000
# count  1600.000000
# max     279.070000
# mean     21.958012
# min    -181.470000
# std      97.601087

# %%
describe_dict = df.transpose().to_dict()
describe_dict
# Out:
# {'25%': {'Arithmancy': 38510.0,
#   'Astronomy': -489.493777,
#   'Herbology': -4.312118,
#   'Defense Against the Dark Arts': -5.259095,
#   'Divination': 3.099,
#   'Muggle Studies': -577.580096,
#   'Ancient Runes': 397.511047,
#   'History of Magic': 2.218653,
#   'Transfiguration': 1026.171713,
#   'Potions': 3.6449,
#   'Care of Magical Creatures': -0.670996,
#   'Charms': -250.64727,
#   'Flying': -41.84},
#  '50%': {'Arithmancy': 49018.0,
#   'Astronomy': 261.644731,
#   'Herbology': 3.469012,
#   'Defense Against the Dark Arts': -2.589342,
#   'Divination': 4.624,
#   'Muggle Studies': -419.164294,
#   'Ancient Runes': 463.918305,
#   'History of Magic': 4.378176,
#   'Transfiguration': 1045.533335,
#   'Potions': 5.877582,
#   'Care of Magical Creatures': -0.043296,
#   'Charms': -244.86751,
#   'Flying': -2.51},
#  '75%': {'Arithmancy': 60828.0,
#   'Astronomy': 525.90954,
#   'Herbology': 5.421046,
#   'Defense Against the Dark Arts': 4.90468,
#   'Divination': 5.667,
#   'Muggle Studies': 254.994857,
#   'Ancient Runes': 597.49223,
#   'History of Magic': 5.825242,
#   'Transfiguration': 1058.445388,
#   'Potions': 8.248789,
#   'Care of Magical Creatures': 0.594446,
#   'Charms': -232.53675,
#   'Flying': 50.89},
#  'count': {'Arithmancy': 1566.0,
#   'Astronomy': 1568.0,
#   'Herbology': 1567.0,
#   'Defense Against the Dark Arts': 1569.0,
#   'Divination': 1561.0,
#   'Muggle Studies': 1565.0,
#   'Ancient Runes': 1565.0,
#   'History of Magic': 1557.0,
#   'Transfiguration': 1566.0,
#   'Potions': 1570.0,
#   'Care of Magical Creatures': 1560.0,
#   'Charms': 1600.0,
#   'Flying': 1600.0},
#  'max': {'Arithmancy': 104956.0,
#   'Astronomy': 1016.21194,
#   'Herbology': 11.612895,
#   'Defense Against the Dark Arts': 9.667405,
#   'Divination': 10.032,
#   'Muggle Studies': 1092.388611,
#   'Ancient Runes': 745.39622,
#   'History of Magic': 11.889713,
#   'Transfiguration': 1098.958201,
#   'Potions': 13.536762,
#   'Care of Magical Creatures': 3.056546,
#   'Charms': -225.42814,
#   'Flying': 279.07},
#  'mean': {'Arithmancy': 49634.570243,
#   'Astronomy': 39.797131,
#   'Herbology': 1.14102,
#   'Defense Against the Dark Arts': -0.387863,
#   'Divination': 3.15391,
#   'Muggle Studies': -224.589915,
#   'Ancient Runes': 495.74797,
#   'History of Magic': 2.963095,
#   'Transfiguration': 1030.096946,
#   'Potions': 5.950373,
#   'Care of Magical Creatures': -0.053427,
#   'Charms': -243.374409,
#   'Flying': 21.958012},
#  'min': {'Arithmancy': -24370.0,
#   'Astronomy': -966.740546,
#   'Herbology': -10.295663,
#   'Defense Against the Dark Arts': -10.162119,
#   'Divination': -8.727,
#   'Muggle Studies': -1086.496835,
#   'Ancient Runes': 283.869609,
#   'History of Magic': -8.858993,
#   'Transfiguration': 906.62732,
#   'Potions': -4.697484,
#   'Care of Magical Creatures': -3.313676,
#   'Charms': -261.04892,
#   'Flying': -181.47},
#  'std': {'Arithmancy': 16674.479577,
#   'Astronomy': 520.13233,
#   'Herbology': 5.218016,
#   'Defense Against the Dark Arts': 5.211132,
#   'Divination': 4.15397,
#   'Muggle Studies': 486.189433,
#   'Ancient Runes': 106.251202,
#   'History of Magic': 4.424353,
#   'Transfiguration': 44.111025,
#   'Potions': 3.146852,
#   'Care of Magical Creatures': 0.971146,
#   'Charms': 8.780895,
#   'Flying': 97.601087}}

# %%
first_line = "{:<10s}".format(" ")
for name in column_names_list[6:11]:
    first_line = first_line +"{:>16s}".format(name[:7])
    #first_line = "{:>10s}".format(name[:10])
print(first_line)

first_line = "{:<10s}".format(" ")
for name in column_names_list[11:16]:
    first_line = first_line +"{:>16s}".format(name[:7])
    #first_line = "{:>10s}".format(name[:10])
print(first_line)

first_line = "{:<10s}".format(" ")
for name in column_names_list[16:]:
    first_line = first_line +"{:>16s}".format(name[:7])
    #first_line = "{:>10s}".format(name[:10])
print(first_line)
# Out:
#                    Arithma         Astrono         Herbolo         Defense         Divinat
#                    Muggle          Ancient         History         Transfi         Potions
#                    Care of          Charms          Flying

# %%
first_line = "{:<10s}".format(" ")
for name in column_names_list[6:11]:
    first_line = first_line +"{:>16s}".format(name[:7])
    #first_line = "{:>10s}".format(name[:10])
print(first_line)
for measure in measure_names_list :
    line = "{:<10s}".format(str(measure))
    #print(s)
    for name in column_names_list[6:11]:
        value = describe_dict[measure][name]
        line = line + "{:16.6f}".format(value)
    print(line)
# Out:
#                    Arithma         Astrono         Herbolo         Defense         Divinat
# count          1566.000000     1568.000000     1567.000000     1569.000000     1561.000000
# mean          49634.570243       39.797131        1.141020       -0.387863        3.153910
# std           16674.479577      520.132330        5.218016        5.211132        4.153970
# min          -24370.000000     -966.740546      -10.295663      -10.162119       -8.727000
# 25%           38510.000000     -489.493777       -4.312118       -5.259095        3.099000
# 50%           49018.000000      261.644731        3.469012       -2.589342        4.624000
# 75%           60828.000000      525.909540        5.421046        4.904680        5.667000
# max          104956.000000     1016.211940       11.612895        9.667405       10.032000

# %%
first_line = "{:<10s}".format(" ")
for name in column_names_list[11:16]:
    first_line = first_line +"{:>16s}".format(name[:7])
    #first_line = "{:>10s}".format(name[:10])
print(first_line)
for measure in measure_names_list:
    line = "{:<10s}".format(str(measure))
    #print(s)
    for name in column_names_list[11:16]:
        value = describe_dict[measure][name]
        line = line + "{:16.6f}".format(value)
    print(line)
# Out:
#                    Muggle          Ancient         History         Transfi         Potions
# count          1565.000000     1565.000000     1557.000000     1566.000000     1570.000000
# mean           -224.589915      495.747970        2.963095     1030.096946        5.950373
# std             486.189433      106.251202        4.424353       44.111025        3.146852
# min           -1086.496835      283.869609       -8.858993      906.627320       -4.697484
# 25%            -577.580096      397.511047        2.218653     1026.171713        3.644900
# 50%            -419.164294      463.918305        4.378176     1045.533335        5.877582
# 75%             254.994857      597.492230        5.825242     1058.445388        8.248789
# max            1092.388611      745.396220       11.889713     1098.958201       13.536762

# %%
first_line = "{:<10s}".format(" ")
for name in column_names_list[16:]:
    first_line = first_line +"{:>16s}".format(name[:7])
    #first_line = "{:>10s}".format(name[:10])
print(first_line)
for measure in measure_names_list :
    line = "{:<10s}".format(str(measure))
    #print(s)
    for name in column_names_list[16:]:
        value = describe_dict[measure][name]
        line = line + "{:16.6f}".format(value)
    print(line)
# Out:
#                    Care of          Charms          Flying
# count          1560.000000     1600.000000     1600.000000
# mean             -0.053427     -243.374409       21.958012
# std               0.971146        8.780895       97.601087
# min              -3.313676     -261.048920     -181.470000
# 25%              -0.670996     -250.647270      -41.840000
# 50%              -0.043296     -244.867510       -2.510000
# 75%               0.594446     -232.536750       50.890000
# max               3.056546     -225.428140      279.070000
